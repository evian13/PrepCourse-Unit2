# %% [markdown]
# ## Unit 2 / Lesson 2 / Project 4
# ## Challenge - What Do You See?
# Let's go out into the world and generate some beautiful visuals. Pick a data source from this aggregation, load the data into a pandas data frame, and generate a series of visuals around that data using pyplot.
#
# Each visualization should be accompanied by 2-3 sentences describing what you think is revealed by this representation. Generate at least <b><u>four</u></b> different visuals, and be sure to use different types as well as the subplot functionality discussed above. And remember: clean and elegant visuals are key to telling a coherent story.
#
# ### Kaggle:
# https://www.kaggle.com/hackerrank/developer-survey-2018

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Kaggle-developer-survey-2018\HackerRank-Developer-Survey-2018-Numeric.csv' , low_memory=False, nrows = 500)

# %%
df.head()
# Out:
#    RespondentID       StartDate         EndDate  CountryNumeric2  \
# 0    6464453728  10/19/17 11:51  10/20/17 12:05            148.0
# 1    6478031510   10/26/17 6:18   10/26/17 7:49            164.0
# 2    6464392829  10/19/17 10:44  10/19/17 10:56             98.0
# 3    6481629912   10/27/17 1:51   10/27/17 2:05             43.0
# 4    6488385057  10/31/17 11:46  10/31/17 11:59              NaN
#
#   q1AgeBeginCoding q2Age q3Gender q4Education q0004_other q5DegreeFocus  \
# 0                3     3        2           3         NaN             1
# 1                3     4        1           7         NaN             2
# 2                2     2        2           3         NaN             2
# 3                2     2        1           5         NaN             1
# 4                3     4        2           5         NaN             0
#
#      ...    q30LearnCodeOther                         q0030_other  q31Level3  \
# 0    ...                    1                            datacamp          1
# 1    ...                    0                                 NaN          1
# 2    ...                    0                                 NaN          1
# 3    ...                    0                                 NaN          1
# 4    ...                    1  Blogs/articles by industry leaders          1
#
#    q32RecommendHackerRank  q0032_other  q33HackerRankChallforJob  \
# 0                       1          NaN                         2
# 1                       1          NaN                         2
# 2                       1          NaN                         2
# 3                       1          NaN                         2
# 4                       1          NaN                         2
#
#   q34PositiveExp  q34IdealLengHackerRankTest  q0035_other q36Level4
# 0            NaN                      #NULL!          NaN         2
# 1            NaN                      #NULL!          NaN         2
# 2            NaN                      #NULL!          NaN         2
# 3            NaN                      #NULL!          NaN         3
# 4            NaN                      #NULL!          NaN         3
#
# [5 rows x 251 columns]

# %%
mp = pd.read_csv('Kaggle-developer-survey-2018\HackerRank-Developer-Survey-2018-Codebook.csv')

# %%
mp.head(20)
# Out:
#                      Data Field  \
# 0                  RespondentID
# 1                     StartDate
# 2                       EndDate
# 3               CountryNumeric2
# 4              q1AgeBeginCoding
# 5                         q2Age
# 6                      q3Gender
# 7                   q4Education
# 8                   q0004_other
# 9                 q5DegreeFocus
# 10                  q0005_other
# 11               q6LearnCodeUni
# 12        q6LearnCodeSelfTaught
# 13        q6LearnCodeAccelTrain
# 14  q6LearnCodeDontKnowHowToYet
# 15             q6LearnCodeOther
# 16                  q0006_other
# 17                     q7Level1
# 18                   q8JobLevel
# 19                  q0008_other
#
#                                       Survey Question  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                    At what age did you start coding
# 5                                How old are you now?
# 6                   What gender do you identify with?
# 7   What is the highest level of education you hav...
# 8                              Other (please specify)
# 9              What is the focus area of your degree?
# 10                             Other (please specify)
# 11                     How did you learn how to code?
# 12                     How did you learn how to code?
# 13                     How did you learn how to code?
# 14                     How did you learn how to code?
# 15                     How did you learn how to code?
# 16                             Other (please specify)
# 17  Success! You completed Level 1 of 4.  To unloc...
# 18  Which of the following best matches your emplo...
# 19                             Other (please specify)
#
#                                               Notes
# 0                                     Respondent ID
# 1               When did they start (date and time)
# 2                 When did they end (date and time)
# 3                      see Country-Code-Mapping.csv
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7   Shown if person chooses "Some College" or above
# 8   Shown if person chooses "Some College" or above
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                             right answer: 1 or C
# 18                                              NaN
# 19                                              NaN

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Columns: 251 entries, RespondentID to q36Level4
# dtypes: float64(2), int64(133), object(116)
# memory usage: 980.5+ KB
# None

# %%
df.describe()
# Out:
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        RespondentID  CountryNumeric2  q1AgeBeginCoding      q2Age   q3Gender  \
# count  5.000000e+01        42.000000         50.000000  50.000000  50.000000
# mean   6.472756e+09       121.809524          3.080000   3.540000   1.280000
# std    8.204873e+06        46.043054          1.065986   0.952119   0.453557
# min    6.458326e+09        27.000000          1.000000   2.000000   1.000000
# 25%    6.464396e+09              NaN          3.000000   3.000000   1.000000
# 50%    6.477593e+09              NaN          3.000000   3.000000   1.000000
# 75%    6.479558e+09              NaN          3.000000   4.000000   2.000000
# max    6.488385e+09       167.000000          8.000000   6.000000   2.000000
#
#        q6LearnCodeUni  q6LearnCodeSelfTaught  q6LearnCodeAccelTrain  \
# count        50.00000              50.000000              50.000000
# mean          0.70000               0.660000               0.100000
# std           0.46291               0.478518               0.303046
# min           0.00000               0.000000               0.000000
# 25%           0.00000               0.000000               0.000000
# 50%           1.00000               1.000000               0.000000
# 75%           1.00000               1.000000               0.000000
# max           1.00000               1.000000               1.000000
#
#        q6LearnCodeDontKnowHowToYet  q6LearnCodeOther    ...      \
# count                    50.000000         50.000000    ...
# mean                      0.080000          0.020000    ...
# std                       0.274048          0.141421    ...
# min                       0.000000          0.000000    ...
# 25%                       0.000000          0.000000    ...
# 50%                       0.000000          0.000000    ...
# 75%                       0.000000          0.000000    ...
# max                       1.000000          1.000000    ...
#
#        q30LearnCodeCompCodingSites  q30LearnCodeOnlineTutorial  \
# count                     50.00000                   50.000000
# mean                       0.14000                    0.320000
# std                        0.35051                    0.471212
# min                        0.00000                    0.000000
# 25%                        0.00000                    0.000000
# 50%                        0.00000                    0.000000
# 75%                        0.00000                    1.000000
# max                        1.00000                    1.000000
#
#        q30LearnCodeBooks  q30LearnCodeAcademicPaper  q30LearnCodeOther  \
# count          50.000000                  50.000000          50.000000
# mean            0.480000                   0.180000           0.180000
# std             0.504672                   0.388088           0.388088
# min             0.000000                   0.000000           0.000000
# 25%             0.000000                   0.000000           0.000000
# 50%             0.000000                   0.000000           0.000000
# 75%             1.000000                   0.000000           0.000000
# max             1.000000                   1.000000           1.000000
#
#        q31Level3  q32RecommendHackerRank  q33HackerRankChallforJob  \
# count  50.000000               50.000000                 50.000000
# mean    1.060000                0.920000                  1.740000
# std     0.313636                0.340468                  0.443087
# min     1.000000                0.000000                  1.000000
# 25%     1.000000                1.000000                  1.250000
# 50%     1.000000                1.000000                  2.000000
# 75%     1.000000                1.000000                  2.000000
# max     3.000000                2.000000                  2.000000
#
#        q34PositiveExp  q36Level4
# count       12.000000  50.000000
# mean         2.833333   2.120000
# std          1.642245   0.627271
# min          0.000000   1.000000
# 25%               NaN   2.000000
# 50%               NaN   2.000000
# 75%               NaN   2.750000
# max          5.000000   3.000000
#
# [8 rows x 142 columns]

# %%
#What unique values does the column hold?
df.q2Age.unique()
# Out:
# array(['3', '4', '2', '5', '6', '#NULL!', '7'], dtype=object)

# %%
# What kind of data is in the column:
df.q2Age.value_counts()
# Out:
# 3    262
# 4    161
# 5     39
# 2     23
# 6     13
# 7      1
# 0      1
# Name: q2Age, dtype: int64

# %%
# Replace '#Null!' with 0 in column 'q2Age'
df.q2Age.replace(['#NULL!'], ['0'], inplace=True)
df.q2Age.unique()
# Out:
# array(['3', '4', '2', '5', '6', '0', '7'], dtype=object)

# %%
# Replace Empty with 0. Not useful as there is no Empty value
df['q2Age'].fillna(0 , inplace = True)
df['q2Age'].head()
# Out:
# 0    3
# 1    4
# 2    2
# 3    2
# 4    4
# Name: q2Age, dtype: object

# %%
# Change data from string to int:
df['q2Age'].apply(int)
df.q2Age.unique()
# Out:
# array(['3', '4', '2', '5', '6', '0', '7'], dtype=object)

# %%
df['q2Age'].plot.hist()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-41a207c17187> in <module>()
# ----> 1 df['q2Age'].plot.hist()
#       2 plt.show()
#
# C:\Anaconda3\lib\site-packages\pandas\tools\plotting.py in hist(self, bins, **kwds)
#    3652         axes : matplotlib.AxesSubplot or np.array of them
#    3653         """
# -> 3654         return self(kind='hist', bins=bins, **kwds)
#    3655
#    3656     def kde(self, **kwds):
#
# C:\Anaconda3\lib\site-packages\pandas\tools\plotting.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3564                            colormap=colormap, table=table, yerr=yerr,
#    3565                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 3566                            **kwds)
#    3567     __call__.__doc__ = plot_series.__doc__
#    3568
#
# C:\Anaconda3\lib\site-packages\pandas\tools\plotting.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2643                  yerr=yerr, xerr=xerr,
#    2644                  label=label, secondary_y=secondary_y,
# -> 2645                  **kwds)
#    2646
#    2647
#
# C:\Anaconda3\lib\site-packages\pandas\tools\plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2439         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2440
# -> 2441     plot_obj.generate()
#    2442     plot_obj.draw()
#    2443     return plot_obj.result
#
# C:\Anaconda3\lib\site-packages\pandas\tools\plotting.py in generate(self)
#    1024     def generate(self):
#    1025         self._args_adjust()
# -> 1026         self._compute_plot_data()
#    1027         self._setup_subplots()
#    1028         self._make_plot()
#
# C:\Anaconda3\lib\site-packages\pandas\tools\plotting.py in _compute_plot_data(self)
#    1133         if is_empty:
#    1134             raise TypeError('Empty {0!r}: no numeric data to '
# -> 1135                             'plot'.format(numeric_data.__class__.__name__))
#    1136
#    1137         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot
